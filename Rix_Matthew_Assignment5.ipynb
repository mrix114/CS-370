# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.9  
LEARNING_RATE = 0.005  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.9  
EXPLORATION_MIN = 0.02  
EXPLORATION_DECAY = 0.99  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.6657303360494523, score: 33
# Scores: (min: 17, avg: 25, max: 33)
#
# Run: 3, exploration: 0.5611728554020801, score: 18
# Scores: (min: 17, avg: 22.666666666666668, max: 33)
#
# Run: 4, exploration: 0.5024395246930774, score: 12
# Scores: (min: 12, avg: 20, max: 33)
#
# Run: 5, exploration: 0.41094877296952315, score: 21
# Scores: (min: 12, avg: 20.2, max: 33)
#
# Run: 6, exploration: 0.3792007999392913, score: 9
# Scores: (min: 9, avg: 18.333333333333332, max: 33)
#
# Run: 7, exploration: 0.3464064710041361, score: 10
# Scores: (min: 9, avg: 17.142857142857142, max: 33)
#
# Run: 8, exploration: 0.3101509650127659, score: 12
# Scores: (min: 9, avg: 16.5, max: 33)
#
# Run: 9, exploration: 0.27216399210211945, score: 14
# Scores: (min: 9, avg: 16.22222222222222, max: 33)
#
# Run: 10, exploration: 0.2486265009292875, score: 10
# Scores: (min: 9, avg: 15.6, max: 33)
#
# Run: 11, exploration: 0.2226048173044814, score: 12
# Scores: (min: 9, avg: 15.272727272727273, max: 33)
#
# Run: 12, exploration: 0.20335333998058858, score: 10
# Scores: (min: 9, avg: 14.833333333333334, max: 33)
#
# Run: 13, exploration: 0.1857667834056723, score: 10
# Scores: (min: 9, avg: 14.461538461538462, max: 33)
#
# Run: 14, exploration: 0.16970116065063942, score: 10
# Scores: (min: 9, avg: 14.142857142857142, max: 33)
#
# Run: 15, exploration: 0.15193994092262147, score: 12
# Scores: (min: 9, avg: 14, max: 33)
#
# Run: 16, exploration: 0.14020177435804057, score: 9
# Scores: (min: 9, avg: 13.6875, max: 33)
#
# Run: 17, exploration: 0.12679597161384093, score: 11
# Scores: (min: 9, avg: 13.529411764705882, max: 33)
#
# Run: 18, exploration: 0.11352528387177409, score: 12
# Scores: (min: 9, avg: 13.444444444444445, max: 33)
#
# Run: 19, exploration: 0.10370730484234203, score: 10
# Scores: (min: 9, avg: 13.263157894736842, max: 33)
#
# Run: 20, exploration: 0.09473841166352313, score: 10
# Scores: (min: 9, avg: 13.1, max: 33)
#
# Run: 21, exploration: 0.0848229241100624, score: 12
# Scores: (min: 9, avg: 13.047619047619047, max: 33)
#
# Run: 22, exploration: 0.07748720415653794, score: 10
# Scores: (min: 9, avg: 12.909090909090908, max: 33)
#
# Run: 23, exploration: 0.07078589745628344, score: 10
# Scores: (min: 9, avg: 12.782608695652174, max: 33)
#
# Run: 24, exploration: 0.06466413820492331, score: 10
# Scores: (min: 9, avg: 12.666666666666666, max: 33)
#
# Run: 25, exploration: 0.05966849044834676, score: 9
# Scores: (min: 9, avg: 12.52, max: 33)
#
# Run: 26, exploration: 0.05396311320431887, score: 11
# Scores: (min: 9, avg: 12.461538461538462, max: 33)
#
# Run: 27, exploration: 0.05029714788292775, score: 8
# Scores: (min: 8, avg: 12.296296296296296, max: 33)
#
# Run: 28, exploration: 0.045487838969386886, score: 11
# Scores: (min: 8, avg: 12.25, max: 33)
#
# Run: 29, exploration: 0.04197366206999334, score: 9
# Scores: (min: 8, avg: 12.137931034482758, max: 33)
#
# Run: 30, exploration: 0.03834366424098881, score: 10
# Scores: (min: 8, avg: 12.066666666666666, max: 33)
#
# Run: 31, exploration: 0.03538141274329799, score: 9
# Scores: (min: 8, avg: 11.96774193548387, max: 33)
#
# Run: 32, exploration: 0.03232153078134019, score: 10
# Scores: (min: 8, avg: 11.90625, max: 33)
#
# Run: 33, exploration: 0.030125778832596328, score: 8
# Scores: (min: 8, avg: 11.787878787878787, max: 33)
#
# Run: 34, exploration: 0.027520418557454327, score: 10
# Scores: (min: 8, avg: 11.735294117647058, max: 33)
#
# Run: 35, exploration: 0.025394320212326658, score: 9
# Scores: (min: 8, avg: 11.657142857142857, max: 33)
#
# Run: 36, exploration: 0.02343247424452811, score: 9
# Scores: (min: 8, avg: 11.583333333333334, max: 33)
#
# Run: 37, exploration: 0.021405969373592626, score: 10
# Scores: (min: 8, avg: 11.54054054054054, max: 33)
#
# Run: 38, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.5, max: 33)
#
# Run: 39, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 11.435897435897436, max: 33)
#
# Run: 40, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 11.375, max: 33)
#
# Run: 41, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.341463414634147, max: 33)
#
# Run: 42, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 11.357142857142858, max: 33)
#
# Run: 43, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 11.30232558139535, max: 33)
#
# Run: 44, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 11.25, max: 33)
#
# Run: 45, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.222222222222221, max: 33)
#
# Run: 46, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.195652173913043, max: 33)
#
# Run: 47, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.170212765957446, max: 33)
#
# Run: 48, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 11.125, max: 33)
#
# Run: 49, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 11.061224489795919, max: 33)
#
# Run: 50, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 11, max: 33)
#
# Run: 51, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.980392156862745, max: 33)
#
# Run: 52, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.961538461538462, max: 33)
#
# Run: 53, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.962264150943396, max: 33)
#
# Run: 54, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.925925925925926, max: 33)
#
# Run: 55, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.89090909090909, max: 33)
#
# Run: 56, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.875, max: 33)
#
# Run: 57, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 10.894736842105264, max: 33)
#
# Run: 58, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.89655172413793, max: 33)
#
# Run: 59, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.88135593220339, max: 33)
#
# Run: 60, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.85, max: 33)
#
# Run: 61, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 10.868852459016393, max: 33)
#
# Run: 62, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 10.887096774193548, max: 33)
#
# Run: 63, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.873015873015873, max: 33)
#
# Run: 64, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.859375, max: 33)
#
# Run: 65, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.830769230769231, max: 33)
#
# Run: 66, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.803030303030303, max: 33)
#
# Run: 67, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.805970149253731, max: 33)
#
# Run: 68, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.779411764705882, max: 33)
#
# Run: 69, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.753623188405797, max: 33)
#
# Run: 70, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.742857142857142, max: 33)
#
# Run: 71, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.732394366197184, max: 33)
#
# Run: 72, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 10.75, max: 33)
#
# Run: 73, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.726027397260275, max: 33)
#
# Run: 74, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.702702702702704, max: 33)
#
# Run: 75, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.706666666666667, max: 33)
#
# Run: 76, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.697368421052632, max: 33)
#
# Run: 77, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 10.662337662337663, max: 33)
#
# Run: 78, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 10.76923076923077, max: 33)
#
# Run: 79, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.759493670886076, max: 33)
#
# Run: 80, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 10.725, max: 33)
#
# Run: 81, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.728395061728396, max: 33)
#
# Run: 82, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.71951219512195, max: 33)
#
# Run: 83, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.710843373493976, max: 33)
#
# Run: 84, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.714285714285714, max: 33)
#
# Run: 85, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.694117647058823, max: 33)
#
# Run: 86, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.674418604651162, max: 33)
#
# Run: 87, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.67816091954023, max: 33)
#
# Run: 88, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 10.784090909090908, max: 33)
#
# Run: 89, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 10.865168539325843, max: 33)
# Run: 90, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.866666666666667, max: 33)
#
# Run: 91, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.846153846153847, max: 33)
#
# Run: 92, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 10.880434782608695, max: 33)
#
# Run: 93, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.86021505376344, max: 33)
#
# Run: 94, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 10.97872340425532, max: 33)
#
# Run: 95, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 10.989473684210527, max: 33)
#
# Run: 96, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 10.96875, max: 33)
#
# Run: 97, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.958762886597938, max: 33)
#
# Run: 98, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 10.948979591836734, max: 33)
#
# Run: 99, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 10.97979797979798, max: 33)
#
# Run: 100, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 11, max: 33)
#
# Run: 101, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 10.94, max: 33)
#
# Run: 102, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 10.79, max: 22)
#
# Run: 103, exploration: 0.02, score: 51
# Scores: (min: 8, avg: 11.12, max: 51)
#
# Run: 104, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 11.12, max: 51)
#
# Run: 105, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 11.02, max: 51)
#
# Run: 106, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 11.08, max: 51)
#
# Run: 107, exploration: 0.02, score: 24
# Scores: (min: 8, avg: 11.22, max: 51)
#
# Run: 108, exploration: 0.02, score: 33
# Scores: (min: 8, avg: 11.43, max: 51)
#
# Run: 109, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 11.47, max: 51)
#
# Run: 110, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 11.48, max: 51)
#
# Run: 111, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 11.58, max: 51)
#
# Run: 112, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 11.68, max: 51)
#
# Run: 113, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 11.69, max: 51)
#
# Run: 114, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 11.72, max: 51)
#
# Run: 115, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 11.82, max: 51)
#
# Run: 116, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 11.88, max: 51)
#
# Run: 117, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 11.95, max: 51)
#
# Run: 118, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 11.96, max: 51)
#
# Run: 119, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 11.96, max: 51)
#
# Run: 120, exploration: 0.02, score: 37
# Scores: (min: 8, avg: 12.23, max: 51)
#
# Run: 121, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 12.24, max: 51)
#
# Run: 122, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 12.27, max: 51)
#
# Run: 123, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 12.33, max: 51)
#
# Run: 124, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 12.42, max: 51)
#
# Run: 125, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 12.53, max: 51)
#
# Run: 126, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 12.55, max: 51)
#
# Run: 127, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 12.59, max: 51)
#
# Run: 128, exploration: 0.02, score: 41
# Scores: (min: 8, avg: 12.89, max: 51)
#
# Run: 129, exploration: 0.02, score: 25
# Scores: (min: 8, avg: 13.05, max: 51)
#
# Run: 130, exploration: 0.02, score: 26
# Scores: (min: 8, avg: 13.21, max: 51)
#
# Run: 131, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 13.3, max: 51)
#
# Run: 132, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 13.35, max: 51)
#
# Run: 133, exploration: 0.02, score: 36
# Scores: (min: 8, avg: 13.63, max: 51)
#
# Run: 134, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 13.82, max: 51)
#
# Run: 135, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 13.85, max: 51)
#
# Run: 136, exploration: 0.02, score: 34
# Scores: (min: 8, avg: 14.1, max: 51)
#
# Run: 137, exploration: 0.02, score: 28
# Scores: (min: 8, avg: 14.28, max: 51)
#
# Run: 138, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 14.32, max: 51)
#
# Run: 139, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 14.37, max: 51)
#
# Run: 140, exploration: 0.02, score: 21
# Scores: (min: 8, avg: 14.49, max: 51)
#
# Run: 141, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 14.57, max: 51)
#
# Run: 142, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 14.6, max: 51)
#
# Run: 143, exploration: 0.02, score: 41
# Scores: (min: 8, avg: 14.92, max: 51)
#
# Run: 144, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 15.02, max: 51)
#
# Run: 145, exploration: 0.02, score: 31
# Scores: (min: 8, avg: 15.23, max: 51)
#
# Run: 146, exploration: 0.02, score: 45
# Scores: (min: 8, avg: 15.58, max: 51)
#
# Run: 147, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 15.61, max: 51)
#
# Run: 148, exploration: 0.02, score: 52
# Scores: (min: 8, avg: 16.04, max: 52)
#
# Run: 149, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 16.1, max: 52)
#
# Run: 150, exploration: 0.02, score: 109
# Scores: (min: 8, avg: 17.11, max: 109)
#
# Run: 151, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 17.16, max: 109)
#
# Run: 152, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 17.19, max: 109)
#
# Run: 153, exploration: 0.02, score: 81
# Scores: (min: 8, avg: 17.89, max: 109)
#
# Run: 154, exploration: 0.02, score: 60
# Scores: (min: 8, avg: 18.4, max: 109)
#
# Run: 155, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 18.6, max: 109)
#
# Run: 156, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 18.7, max: 109)
#
# Run: 157, exploration: 0.02, score: 58
# Scores: (min: 8, avg: 19.16, max: 109)
#
# Run: 158, exploration: 0.02, score: 32
# Scores: (min: 8, avg: 19.37, max: 109)
#
# Run: 159, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 19.47, max: 109)
#
# Run: 160, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 19.67, max: 109)
#
# Run: 161, exploration: 0.02, score: 32
# Scores: (min: 8, avg: 19.87, max: 109)
#
# Run: 162, exploration: 0.02, score: 17
# Scores: (min: 8, avg: 19.92, max: 109)
#
# Run: 163, exploration: 0.02, score: 17
# Scores: (min: 8, avg: 19.99, max: 109)
#
# Run: 164, exploration: 0.02, score: 61
# Scores: (min: 8, avg: 20.5, max: 109)
#
# Run: 165, exploration: 0.02, score: 54
# Scores: (min: 8, avg: 20.95, max: 109)
#
# Run: 166, exploration: 0.02, score: 47
# Scores: (min: 8, avg: 21.33, max: 109)
#
# Run: 167, exploration: 0.02, score: 55
# Scores: (min: 8, avg: 21.77, max: 109)
#
# Run: 168, exploration: 0.02, score: 82
# Scores: (min: 8, avg: 22.5, max: 109)
#
# Run: 169, exploration: 0.02, score: 88
# Scores: (min: 8, avg: 23.29, max: 109)
#
# Run: 170, exploration: 0.02, score: 81
# Scores: (min: 8, avg: 24, max: 109)
#
# Run: 171, exploration: 0.02, score: 119
# Scores: (min: 8, avg: 25.09, max: 119)
#
# Run: 172, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 25.13, max: 119)
#
# Run: 173, exploration: 0.02, score: 54
# Scores: (min: 8, avg: 25.58, max: 119)
#
# Run: 174, exploration: 0.02, score: 88
# Scores: (min: 8, avg: 26.37, max: 119)
#
# Run: 175, exploration: 0.02, score: 60
# Scores: (min: 8, avg: 26.86, max: 119)
#
# Run: 176, exploration: 0.02, score: 96
# Scores: (min: 8, avg: 27.72, max: 119)
#
# Run: 177, exploration: 0.02, score: 74
# Scores: (min: 8, avg: 28.38, max: 119)
#
# Run: 178, exploration: 0.02, score: 33
# Scores: (min: 8, avg: 28.52, max: 119)
#
# Run: 179, exploration: 0.02, score: 35
# Scores: (min: 8, avg: 28.77, max: 119)
#
# Run: 180, exploration: 0.02, score: 81
# Scores: (min: 9, avg: 29.5, max: 119)
#
# Run: 181, exploration: 0.02, score: 32
# Scores: (min: 9, avg: 29.71, max: 119)
#
# Run: 182, exploration: 0.02, score: 9
# Scores: (min: 9, avg: 29.7, max: 119)
#
# Run: 183, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 29.68, max: 119)
#
# Run: 184, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.66, max: 119)
#
# Run: 185, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.66, max: 119)
#
# Run: 186, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.67, max: 119)
#
# Run: 187, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.65, max: 119)
#
# Run: 188, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 29.56, max: 119)
#
# Run: 189, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.47, max: 119)
#
# Run: 190, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 29.48, max: 119)
#
# Run: 191, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.49, max: 119)
#
# Run: 192, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.45, max: 119)
#
# Run: 193, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.46, max: 119)
# Run: 194, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.34, max: 119)
#
# Run: 195, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.32, max: 119)
#
# Run: 196, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.32, max: 119)
#
# Run: 197, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.31, max: 119)
#
# Run: 198, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.31, max: 119)
#
# Run: 199, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 29.25, max: 119)
#
# Run: 200, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.22, max: 119)
#
# Run: 201, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.21, max: 119)
#
# Run: 202, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.12, max: 119)
#
# Run: 203, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.7, max: 119)
#
# Run: 204, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 28.68, max: 119)
#
# Run: 205, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.66, max: 119)
#
# Run: 206, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.6, max: 119)
#
# Run: 207, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 28.46, max: 119)
#
# Run: 208, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.22, max: 119)
#
# Run: 209, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.13, max: 119)
#
# Run: 210, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 28.12, max: 119)
#
# Run: 211, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 27.99, max: 119)
#
# Run: 212, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 27.88, max: 119)
#
# Run: 213, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 27.85, max: 119)
#
# Run: 214, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 27.81, max: 119)
#
# Run: 215, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.69, max: 119)
#
# Run: 216, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.64, max: 119)
#
# Run: 217, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 27.55, max: 119)
#
# Run: 218, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.52, max: 119)
#
# Run: 219, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.52, max: 119)
#
# Run: 220, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.25, max: 119)
#
# Run: 221, exploration: 0.02, score: 21
# Scores: (min: 8, avg: 27.33, max: 119)
#
# Run: 222, exploration: 0.02, score: 24
# Scores: (min: 8, avg: 27.44, max: 119)
#
# Run: 223, exploration: 0.02, score: 27
# Scores: (min: 8, avg: 27.55, max: 119)
#
# Run: 224, exploration: 0.02, score: 48
# Scores: (min: 8, avg: 27.84, max: 119)
#
# Run: 225, exploration: 0.02, score: 65
# Scores: (min: 8, avg: 28.29, max: 119)
#
# Run: 226, exploration: 0.02, score: 31
# Scores: (min: 8, avg: 28.47, max: 119)
#
# Run: 227, exploration: 0.02, score: 37
# Scores: (min: 8, avg: 28.72, max: 119)
#
# Run: 228, exploration: 0.02, score: 36
# Scores: (min: 8, avg: 28.67, max: 119)
#
# Run: 229, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 28.64, max: 119)
#
# Run: 230, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 28.5, max: 119)
#
# Run: 231, exploration: 0.02, score: 34
# Scores: (min: 8, avg: 28.66, max: 119)
#
# Run: 232, exploration: 0.02, score: 85
# Scores: (min: 8, avg: 29.36, max: 119)
#
# Run: 233, exploration: 0.02, score: 60
# Scores: (min: 8, avg: 29.6, max: 119)
#
# Run: 234, exploration: 0.02, score: 126
# Scores: (min: 8, avg: 30.57, max: 126)
#
# Run: 235, exploration: 0.02, score: 80
# Scores: (min: 8, avg: 31.25, max: 126)
#
# Run: 236, exploration: 0.02, score: 42
# Scores: (min: 8, avg: 31.33, max: 126)
#
# Run: 237, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 31.15, max: 126)
#
# Run: 238, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 31.11, max: 126)
#
# Run: 239, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 31.07, max: 126)
#
# Run: 240, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 30.95, max: 126)
#
# Run: 241, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 30.86, max: 126)
#
# Run: 242, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 30.8, max: 126)
#
# Run: 243, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 30.49, max: 126)
#
# Run: 244, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 30.39, max: 126)
#
# Run: 245, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 30.17, max: 126)
#
# Run: 246, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.81, max: 126)
#
# Run: 247, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 29.77, max: 126)
#
# Run: 248, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.35, max: 126)
#
# Run: 249, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 29.31, max: 126)
#
# Run: 250, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.31, max: 126)
#
# Run: 251, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 28.25, max: 126)
#
# Run: 252, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 28.22, max: 126)
#
# Run: 253, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.51, max: 126)
#
# Run: 254, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 27.01, max: 126)
#
# Run: 255, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 26.81, max: 126)
#
# Run: 256, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 26.72, max: 126)
#
# Run: 257, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 26.24, max: 126)
#
# Run: 258, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 26.02, max: 126)
#
# Run: 259, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 25.9, max: 126)
#
# Run: 260, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 25.69, max: 126)
#
# Run: 261, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 25.47, max: 126)
#
# Run: 262, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 25.4, max: 126)
#
# Run: 263, exploration: 0.02, score: 8
# Scores: (min: 8, avg: 25.31, max: 126)
#
# Run: 264, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 24.81, max: 126)
#
# Run: 265, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 24.42, max: 126)
#
# Run: 266, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 24.09, max: 126)
#
# Run: 267, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 23.77, max: 126)
#
# Run: 268, exploration: 0.02, score: 17
# Scores: (min: 8, avg: 23.12, max: 126)
#
# Run: 269, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 22.44, max: 126)
#
# Run: 270, exploration: 0.02, score: 40
# Scores: (min: 8, avg: 22.03, max: 126)
#
# Run: 271, exploration: 0.02, score: 68
# Scores: (min: 8, avg: 21.52, max: 126)
#
# Run: 272, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 21.51, max: 126)
#
# Run: 273, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 21.16, max: 126)
#
# Run: 274, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 20.44, max: 126)
#
# Run: 275, exploration: 0.02, score: 43
# Scores: (min: 8, avg: 20.27, max: 126)
#
# Run: 276, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 19.5, max: 126)
#
# Run: 277, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 18.99, max: 126)
#
# Run: 278, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 18.81, max: 126)
#
# Run: 279, exploration: 0.02, score: 35
# Scores: (min: 8, avg: 18.81, max: 126)
#
# Run: 280, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 18.12, max: 126)
#
# Run: 281, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 17.91, max: 126)
#
# Run: 282, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 17.94, max: 126)
#
# Run: 283, exploration: 0.02, score: 21
# Scores: (min: 8, avg: 18.07, max: 126)
#
# Run: 284, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 18.27, max: 126)
#
# Run: 285, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 18.29, max: 126)
#
# Run: 286, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 18.35, max: 126)
#
# Run: 287, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 18.46, max: 126)
#
# Run: 288, exploration: 0.02, score: 31
# Scores: (min: 8, avg: 18.66, max: 126)
#
# Run: 289, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 18.72, max: 126)
#
# Run: 290, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 18.71, max: 126)
#
# Run: 291, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 18.76, max: 126)
#
# Run: 292, exploration: 0.02, score: 25
# Scores: (min: 8, avg: 18.91, max: 126)
#
# Run: 293, exploration: 0.02, score: 9
# Scores: (min: 8, avg: 18.9, max: 126)
#
# Run: 294, exploration: 0.02, score: 32
# Scores: (min: 8, avg: 19.12, max: 126)
#
# Run: 295, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 19.31, max: 126)
#
# Run: 296, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 19.38, max: 126)
#
# Run: 297, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 19.48, max: 126)
#
# Run: 298, exploration: 0.02, score: 34
# Scores: (min: 8, avg: 19.72, max: 126)
# Run: 299, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 19.86, max: 126)
#
# Run: 300, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 19.91, max: 126)
#
# Run: 301, exploration: 0.02, score: 42
# Scores: (min: 8, avg: 20.23, max: 126)
#
# Run: 302, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 20.28, max: 126)
#
# Run: 303, exploration: 0.02, score: 65
# Scores: (min: 8, avg: 20.84, max: 126)
#
# Run: 304, exploration: 0.02, score: 36
# Scores: (min: 8, avg: 21.1, max: 126)
#
# Run: 305, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 21.21, max: 126)
#
# Run: 306, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 21.35, max: 126)
#
# Run: 307, exploration: 0.02, score: 26
# Scores: (min: 8, avg: 21.51, max: 126)
#
# Run: 308, exploration: 0.02, score: 50
# Scores: (min: 8, avg: 21.92, max: 126)
#
# Run: 309, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 22.05, max: 126)
#
# Run: 310, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 22.09, max: 126)
#
# Run: 311, exploration: 0.02, score: 27
# Scores: (min: 8, avg: 22.27, max: 126)
#
# Run: 312, exploration: 0.02, score: 10
# Scores: (min: 8, avg: 22.28, max: 126)
#
# Run: 313, exploration: 0.02, score: 75
# Scores: (min: 8, avg: 22.95, max: 126)
#
# Run: 314, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 23, max: 126)
#
# Run: 315, exploration: 0.02, score: 22
# Scores: (min: 8, avg: 23.12, max: 126)
#
# Run: 316, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 23.22, max: 126)
#
# Run: 317, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 23.29, max: 126)
#
# Run: 318, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 23.38, max: 126)
#
# Run: 319, exploration: 0.02, score: 27
# Scores: (min: 8, avg: 23.55, max: 126)
#
# Run: 320, exploration: 0.02, score: 25
# Scores: (min: 8, avg: 23.7, max: 126)
#
# Run: 321, exploration: 0.02, score: 74
# Scores: (min: 8, avg: 24.23, max: 126)
#
# Run: 322, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 24.12, max: 126)
#
# Run: 323, exploration: 0.02, score: 41
# Scores: (min: 8, avg: 24.26, max: 126)
#
# Run: 324, exploration: 0.02, score: 28
# Scores: (min: 8, avg: 24.06, max: 126)
#
# Run: 325, exploration: 0.02, score: 104
# Scores: (min: 8, avg: 24.45, max: 126)
#
# Run: 326, exploration: 0.02, score: 58
# Scores: (min: 8, avg: 24.72, max: 126)
#
# Run: 327, exploration: 0.02, score: 26
# Scores: (min: 8, avg: 24.61, max: 126)
#
# Run: 328, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 24.48, max: 126)
#
# Run: 329, exploration: 0.02, score: 41
# Scores: (min: 8, avg: 24.67, max: 126)
#
# Run: 330, exploration: 0.02, score: 40
# Scores: (min: 8, avg: 24.95, max: 126)
#
# Run: 331, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 24.79, max: 126)
#
# Run: 332, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 24.08, max: 126)
#
# Run: 333, exploration: 0.02, score: 48
# Scores: (min: 8, avg: 23.96, max: 126)
#
# Run: 334, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 22.85, max: 104)
#
# Run: 335, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 22.19, max: 104)
#
# Run: 336, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 21.89, max: 104)
#
# Run: 337, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 21.99, max: 104)
#
# Run: 338, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 22.12, max: 104)
#
# Run: 339, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 22.13, max: 104)
#
# Run: 340, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 22.18, max: 104)
#
# Run: 341, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 22.24, max: 104)
#
# Run: 342, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 22.33, max: 104)
#
# Run: 343, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 22.36, max: 104)
#
# Run: 344, exploration: 0.02, score: 11
# Scores: (min: 8, avg: 22.38, max: 104)
#
# Run: 345, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 22.47, max: 104)
#
# Run: 346, exploration: 0.02, score: 18
# Scores: (min: 8, avg: 22.56, max: 104)
#
# Run: 347, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 22.66, max: 104)
#
# Run: 348, exploration: 0.02, score: 21
# Scores: (min: 8, avg: 22.77, max: 104)
#
# Run: 349, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 22.9, max: 104)
#
# Run: 350, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 23.01, max: 104)
#
# Run: 351, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 23.08, max: 104)
#
# Run: 352, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 23.21, max: 104)
#
# Run: 353, exploration: 0.02, score: 17
# Scores: (min: 8, avg: 23.28, max: 104)
#
# Run: 354, exploration: 0.02, score: 15
# Scores: (min: 8, avg: 23.33, max: 104)
#
# Run: 355, exploration: 0.02, score: 16
# Scores: (min: 8, avg: 23.4, max: 104)
#
# Run: 356, exploration: 0.02, score: 17
# Scores: (min: 8, avg: 23.46, max: 104)
#
# Run: 357, exploration: 0.02, score: 23
# Scores: (min: 8, avg: 23.59, max: 104)
#
# Run: 358, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 23.61, max: 104)
#
# Run: 359, exploration: 0.02, score: 29
# Scores: (min: 8, avg: 23.82, max: 104)
#
# Run: 360, exploration: 0.02, score: 14
# Scores: (min: 8, avg: 23.88, max: 104)
#
# Run: 361, exploration: 0.02, score: 19
# Scores: (min: 8, avg: 23.97, max: 104)
#
# Run: 362, exploration: 0.02, score: 12
# Scores: (min: 8, avg: 23.99, max: 104)
#
# Run: 363, exploration: 0.02, score: 20
# Scores: (min: 9, avg: 24.11, max: 104)
#
# Run: 364, exploration: 0.02, score: 14
# Scores: (min: 9, avg: 24.14, max: 104)
#
# Run: 365, exploration: 0.02, score: 19
# Scores: (min: 9, avg: 24.18, max: 104)
#
# Run: 366, exploration: 0.02, score: 35
# Scores: (min: 9, avg: 24.39, max: 104)
#
# Run: 367, exploration: 0.02, score: 31
# Scores: (min: 9, avg: 24.47, max: 104)
#
# Run: 368, exploration: 0.02, score: 12
# Scores: (min: 9, avg: 24.42, max: 104)
#
# Run: 369, exploration: 0.02, score: 17
# Scores: (min: 9, avg: 24.39, max: 104)
#
# Run: 370, exploration: 0.02, score: 58
# Scores: (min: 9, avg: 24.57, max: 104)
#
# Run: 371, exploration: 0.02, score: 21
# Scores: (min: 9, avg: 24.1, max: 104)
#
# Run: 372, exploration: 0.02, score: 51
# Scores: (min: 9, avg: 24.46, max: 104)
#
# Run: 373, exploration: 0.02, score: 69
# Scores: (min: 9, avg: 24.96, max: 104)
#
# Run: 374, exploration: 0.02, score: 58
# Scores: (min: 9, avg: 25.38, max: 104)
#
# Run: 375, exploration: 0.02, score: 20
# Scores: (min: 9, avg: 25.15, max: 104)
#
# Run: 376, exploration: 0.02, score: 35
# Scores: (min: 9, avg: 25.31, max: 104)
#
# Run: 377, exploration: 0.02, score: 25
# Scores: (min: 9, avg: 25.33, max: 104)
#
# Run: 378, exploration: 0.02, score: 77
# Scores: (min: 9, avg: 25.95, max: 104)
#
# Run: 379, exploration: 0.02, score: 51
# Scores: (min: 9, avg: 26.11, max: 104)
#
# Run: 380, exploration: 0.02, score: 67
# Scores: (min: 9, avg: 26.66, max: 104)
#
# Run: 381, exploration: 0.02, score: 20
# Scores: (min: 9, avg: 26.75, max: 104)
#
# Run: 382, exploration: 0.02, score: 14
# Scores: (min: 9, avg: 26.77, max: 104)
#
# Run: 383, exploration: 0.02, score: 41
# Scores: (min: 9, avg: 26.97, max: 104)
#
# Run: 384, exploration: 0.02, score: 10
# Scores: (min: 9, avg: 26.78, max: 104)
#
# Run: 385, exploration: 0.02, score: 9
# Scores: (min: 9, avg: 26.76, max: 104)
#
# Run: 386, exploration: 0.02, score: 103
# Scores: (min: 9, avg: 27.63, max: 104)
#
# Run: 387, exploration: 0.02, score: 63
# Scores: (min: 9, avg: 28.06, max: 104)
#
# Run: 388, exploration: 0.02, score: 65
# Scores: (min: 9, avg: 28.4, max: 104)
#
# Run: 389, exploration: 0.02, score: 61
# Scores: (min: 9, avg: 28.86, max: 104)
#
# Run: 390, exploration: 0.02, score: 71
# Scores: (min: 9, avg: 29.46, max: 104)
#
# Run: 391, exploration: 0.02, score: 27
# Scores: (min: 9, avg: 29.58, max: 104)
#
# Run: 392, exploration: 0.02, score: 94
# Scores: (min: 9, avg: 30.27, max: 104)
#
# Run: 393, exploration: 0.02, score: 64
# Scores: (min: 9, avg: 30.82, max: 104)
#
# Run: 394, exploration: 0.02, score: 69
# Scores: (min: 9, avg: 31.19, max: 104)
#
# Run: 395, exploration: 0.02, score: 43
# Scores: (min: 9, avg: 31.33, max: 104)
#
# Run: 396, exploration: 0.02, score: 26
# Scores: (min: 9, avg: 31.43, max: 104)
#
# Run: 397, exploration: 0.02, score: 86
# Scores: (min: 9, avg: 32.1, max: 104)
#
# Run: 398, exploration: 0.02, score: 119
# Scores: (min: 9, avg: 32.95, max: 119)
#
# Run: 399, exploration: 0.02, score: 78
# Scores: (min: 9, avg: 33.51, max: 119)
#
# Run: 400, exploration: 0.02, score: 62
# Scores: (min: 9, avg: 33.98, max: 119)
#
# Run: 401, exploration: 0.02, score: 29
# Scores: (min: 9, avg: 33.85, max: 119)
#
# Run: 402, exploration: 0.02, score: 94
# Scores: (min: 9, avg: 34.65, max: 119)
# Run: 403, exploration: 0.02, score: 116
# Scores: (min: 9, avg: 35.16, max: 119)
#
# Run: 404, exploration: 0.02, score: 88
# Scores: (min: 9, avg: 35.68, max: 119)
#
# Run: 405, exploration: 0.02, score: 101
# Scores: (min: 9, avg: 36.49, max: 119)
#
# Run: 406, exploration: 0.02, score: 15
# Scores: (min: 9, avg: 36.41, max: 119)
#
# Run: 407, exploration: 0.02, score: 151
# Scores: (min: 9, avg: 37.66, max: 151)
#
# Run: 408, exploration: 0.02, score: 111
# Scores: (min: 9, avg: 38.27, max: 151)
#
# Run: 409, exploration: 0.02, score: 152
# Scores: (min: 9, avg: 39.57, max: 152)
#
# Run: 410, exploration: 0.02, score: 170
# Scores: (min: 9, avg: 41.13, max: 170)
#
# Run: 411, exploration: 0.02, score: 10
# Scores: (min: 9, avg: 40.96, max: 170)
#
# Run: 412, exploration: 0.02, score: 14
# Scores: (min: 9, avg: 41, max: 170)
#
# Run: 413, exploration: 0.02, score: 20
# Scores: (min: 9, avg: 40.45, max: 170)
#
# Run: 414, exploration: 0.02, score: 14
# Scores: (min: 9, avg: 40.45, max: 170)
#
# Run: 415, exploration: 0.02, score: 10
# Scores: (min: 9, avg: 40.33, max: 170)
#
# Run: 416, exploration: 0.02, score: 11
# Scores: (min: 9, avg: 40.24, max: 170)
#
# Run: 417, exploration: 0.02, score: 9
# Scores: (min: 9, avg: 40.17, max: 170)
#
# Run: 418, exploration: 0.02, score: 12
# Scores: (min: 9, avg: 40.1, max: 170)
#
# Run: 419, exploration: 0.02, score: 14
# Scores: (min: 9, avg: 39.97, max: 170)
#
# Run: 420, exploration: 0.02, score: 301
# Scores: (min: 9, avg: 42.73, max: 301)
#
# Run: 421, exploration: 0.02, score: 178
# Scores: (min: 9, avg: 43.77, max: 301)
#
# Run: 422, exploration: 0.02, score: 186
# Scores: (min: 9, avg: 45.5, max: 301)
#
# Run: 423, exploration: 0.02, score: 235
# Scores: (min: 9, avg: 47.44, max: 301)
#
# Run: 424, exploration: 0.02, score: 285
# Scores: (min: 9, avg: 50.01, max: 301)
#
# Run: 425, exploration: 0.02, score: 139
# Scores: (min: 9, avg: 50.36, max: 301)
#
# Run: 426, exploration: 0.02, score: 307
# Scores: (min: 9, avg: 52.85, max: 307)
#
# Run: 427, exploration: 0.02, score: 210
# Scores: (min: 9, avg: 54.69, max: 307)
#
# Run: 428, exploration: 0.02, score: 137
# Scores: (min: 9, avg: 55.83, max: 307)
#
# Run: 429, exploration: 0.02, score: 81
# Scores: (min: 9, avg: 56.23, max: 307)
#
# Run: 430, exploration: 0.02, score: 369
# Scores: (min: 9, avg: 59.52, max: 369)
#
# Run: 431, exploration: 0.02, score: 500
# Scores: (min: 9, avg: 64.34, max: 500)
#
# Run: 432, exploration: 0.02, score: 400
# Scores: (min: 9, avg: 68.2, max: 500)
#
# Run: 433, exploration: 0.02, score: 169
# Scores: (min: 9, avg: 69.41, max: 500)
#
# Run: 434, exploration: 0.02, score: 150
# Scores: (min: 9, avg: 70.76, max: 500)
#
# Run: 435, exploration: 0.02, score: 162
# Scores: (min: 9, avg: 72.24, max: 500)
#
# Run: 436, exploration: 0.02, score: 131
# Scores: (min: 9, avg: 73.43, max: 500)
#
# Run: 437, exploration: 0.02, score: 176
# Scores: (min: 9, avg: 74.99, max: 500)
#
# Run: 438, exploration: 0.02, score: 500
# Scores: (min: 9, avg: 79.76, max: 500)
#
# Run: 439, exploration: 0.02, score: 191
# Scores: (min: 9, avg: 81.56, max: 500)
#
# Run: 440, exploration: 0.02, score: 137
# Scores: (min: 9, avg: 82.79, max: 500)
#
# Run: 441, exploration: 0.02, score: 122
# Scores: (min: 9, avg: 83.86, max: 500)
#
# Run: 442, exploration: 0.02, score: 199
# Scores: (min: 9, avg: 85.67, max: 500)
#
# Run: 443, exploration: 0.02, score: 257
# Scores: (min: 9, avg: 88.11, max: 500)
#
# Run: 444, exploration: 0.02, score: 328
# Scores: (min: 9, avg: 91.28, max: 500)
#
# Run: 445, exploration: 0.02, score: 500
# Scores: (min: 9, avg: 96.1, max: 500)
#
# Run: 446, exploration: 0.02, score: 164
# Scores: (min: 9, avg: 97.56, max: 500)
#
# Run: 447, exploration: 0.02, score: 500
# Scores: (min: 9, avg: 102.37, max: 500)
#
# Run: 448, exploration: 0.02, score: 174
# Scores: (min: 9, avg: 103.9, max: 500)
#
# Run: 449, exploration: 0.02, score: 221
# Scores: (min: 9, avg: 105.88, max: 500)
#
# Run: 450, exploration: 0.02, score: 147
# Scores: (min: 9, avg: 107.15, max: 500)
#
# Run: 451, exploration: 0.02, score: 157
# Scores: (min: 9, avg: 108.56, max: 500)
#
# Run: 452, exploration: 0.02, score: 141
# Scores: (min: 9, avg: 109.74, max: 500)
#
# Run: 453, exploration: 0.02, score: 205
# Scores: (min: 9, avg: 111.62, max: 500)
#
# Run: 454, exploration: 0.02, score: 150
# Scores: (min: 9, avg: 112.97, max: 500)
#
# Run: 455, exploration: 0.02, score: 71
# Scores: (min: 9, avg: 113.52, max: 500)
#
# Run: 456, exploration: 0.02, score: 34
# Scores: (min: 9, avg: 113.69, max: 500)
#
# Run: 457, exploration: 0.02, score: 241
# Scores: (min: 9, avg: 115.87, max: 500)
#
# Run: 458, exploration: 0.02, score: 161
# Scores: (min: 9, avg: 117.36, max: 500)
#
# Run: 459, exploration: 0.02, score: 277
# Scores: (min: 9, avg: 119.84, max: 500)
#
# Run: 460, exploration: 0.02, score: 136
# Scores: (min: 9, avg: 121.06, max: 500)
#
# Run: 461, exploration: 0.02, score: 157
# Scores: (min: 9, avg: 122.44, max: 500)
#
# Run: 462, exploration: 0.02, score: 134
# Scores: (min: 9, avg: 123.66, max: 500)
#
# Run: 463, exploration: 0.02, score: 115
# Scores: (min: 9, avg: 124.61, max: 500)
#
# Run: 464, exploration: 0.02, score: 262
# Scores: (min: 9, avg: 127.09, max: 500)
#
# Run: 465, exploration: 0.02, score: 128
# Scores: (min: 9, avg: 128.18, max: 500)
#
# Run: 466, exploration: 0.02, score: 160
# Scores: (min: 9, avg: 129.43, max: 500)
#
# Run: 467, exploration: 0.02, score: 165
# Scores: (min: 9, avg: 130.77, max: 500)
#
# Run: 468, exploration: 0.02, score: 167
# Scores: (min: 9, avg: 132.32, max: 500)
#
# Run: 469, exploration: 0.02, score: 85
# Scores: (min: 9, avg: 133, max: 500)
#
# Run: 470, exploration: 0.02, score: 172
# Scores: (min: 9, avg: 134.14, max: 500)
#
# Run: 471, exploration: 0.02, score: 147
# Scores: (min: 9, avg: 135.4, max: 500)
#
# Run: 472, exploration: 0.02, score: 104
# Scores: (min: 9, avg: 135.93, max: 500)
#
# Run: 473, exploration: 0.02, score: 99
# Scores: (min: 9, avg: 136.23, max: 500)
#
# Run: 474, exploration: 0.02, score: 122
# Scores: (min: 9, avg: 136.87, max: 500)
#
# Run: 475, exploration: 0.02, score: 35
# Scores: (min: 9, avg: 137.02, max: 500)
#
# Run: 476, exploration: 0.02, score: 30
# Scores: (min: 9, avg: 136.97, max: 500)
#
# Run: 477, exploration: 0.02, score: 76
# Scores: (min: 9, avg: 137.48, max: 500)
#
# Run: 478, exploration: 0.02, score: 129
# Scores: (min: 9, avg: 138, max: 500)
#
# Run: 479, exploration: 0.02, score: 130
# Scores: (min: 9, avg: 138.79, max: 500)
#
# Run: 480, exploration: 0.02, score: 82
# Scores: (min: 9, avg: 138.94, max: 500)
#
# Run: 481, exploration: 0.02, score: 109
# Scores: (min: 9, avg: 139.83, max: 500)
#
# Run: 482, exploration: 0.02, score: 114
# Scores: (min: 9, avg: 140.83, max: 500)
#
# Run: 483, exploration: 0.02, score: 31
# Scores: (min: 9, avg: 140.73, max: 500)
#
# Run: 484, exploration: 0.02, score: 147
# Scores: (min: 9, avg: 142.1, max: 500)
#
# Run: 485, exploration: 0.02, score: 166
# Scores: (min: 9, avg: 143.67, max: 500)
#
# Run: 486, exploration: 0.02, score: 77
# Scores: (min: 9, avg: 143.41, max: 500)
#
# Run: 487, exploration: 0.02, score: 115
# Scores: (min: 9, avg: 143.93, max: 500)
#
# Run: 488, exploration: 0.02, score: 226
# Scores: (min: 9, avg: 145.54, max: 500)
#
# Run: 489, exploration: 0.02, score: 164
# Scores: (min: 9, avg: 146.57, max: 500)
#
# Run: 490, exploration: 0.02, score: 108
# Scores: (min: 9, avg: 146.94, max: 500)
#
# Run: 491, exploration: 0.02, score: 126
# Scores: (min: 9, avg: 147.93, max: 500)
#
# Run: 492, exploration: 0.02, score: 193
# Scores: (min: 9, avg: 148.92, max: 500)
#
# Run: 493, exploration: 0.02, score: 146
# Scores: (min: 9, avg: 149.74, max: 500)
#
# Run: 494, exploration: 0.02, score: 116
# Scores: (min: 9, avg: 150.21, max: 500)
#
# Run: 495, exploration: 0.02, score: 167
# Scores: (min: 9, avg: 151.45, max: 500)
#
# Run: 496, exploration: 0.02, score: 125
# Scores: (min: 9, avg: 152.44, max: 500)
#
# Run: 497, exploration: 0.02, score: 128
# Scores: (min: 9, avg: 152.86, max: 500)
#
# Run: 498, exploration: 0.02, score: 15
# Scores: (min: 9, avg: 151.82, max: 500)
#
# Run: 499, exploration: 0.02, score: 106
# Scores: (min: 9, avg: 152.1, max: 500)
#
# Run: 500, exploration: 0.02, score: 114
# Scores: (min: 9, avg: 152.62, max: 500)
#
# Run: 501, exploration: 0.02, score: 74
# Scores: (min: 9, avg: 153.07, max: 500)
#
# Run: 502, exploration: 0.02, score: 244
# Scores: (min: 9, avg: 154.57, max: 500)
#
# Run: 503, exploration: 0.02, score: 118
# Scores: (min: 9, avg: 154.59, max: 500)
#
# Run: 504, exploration: 0.02, score: 149
# Scores: (min: 9, avg: 155.2, max: 500)
#
# Run: 505, exploration: 0.02, score: 135
# Scores: (min: 9, avg: 155.54, max: 500)
# Run: 506, exploration: 0.02, score: 65
# Scores: (min: 9, avg: 156.04, max: 500)
#
# Run: 507, exploration: 0.02, score: 124
# Scores: (min: 9, avg: 155.77, max: 500)
#
# Run: 508, exploration: 0.02, score: 192
# Scores: (min: 9, avg: 156.58, max: 500)
#
# Run: 509, exploration: 0.02, score: 141
# Scores: (min: 9, avg: 156.47, max: 500)
#
# Run: 510, exploration: 0.02, score: 199
# Scores: (min: 9, avg: 156.76, max: 500)
#
# Run: 511, exploration: 0.02, score: 238
# Scores: (min: 9, avg: 159.04, max: 500)
#
# Run: 512, exploration: 0.02, score: 152
# Scores: (min: 9, avg: 160.42, max: 500)
#
# Run: 513, exploration: 0.02, score: 151
# Scores: (min: 9, avg: 161.73, max: 500)
#
# Run: 514, exploration: 0.02, score: 217
# Scores: (min: 9, avg: 163.76, max: 500)
#
# Run: 515, exploration: 0.02, score: 201
# Scores: (min: 9, avg: 165.67, max: 500)
#
# Run: 516, exploration: 0.02, score: 125
# Scores: (min: 9, avg: 166.81, max: 500)
#
# Run: 517, exploration: 0.02, score: 253
# Scores: (min: 12, avg: 169.25, max: 500)
#
# Run: 518, exploration: 0.02, score: 180
# Scores: (min: 14, avg: 170.93, max: 500)
#
# Run: 519, exploration: 0.02, score: 105
# Scores: (min: 15, avg: 171.84, max: 500)
#
# Run: 520, exploration: 0.02, score: 159
# Scores: (min: 15, avg: 170.42, max: 500)
#
# Run: 521, exploration: 0.02, score: 177
# Scores: (min: 15, avg: 170.41, max: 500)
#
# Run: 522, exploration: 0.02, score: 195
# Scores: (min: 15, avg: 170.5, max: 500)
#
# Run: 523, exploration: 0.02, score: 317
# Scores: (min: 15, avg: 171.32, max: 500)
#
# Run: 524, exploration: 0.02, score: 11
# Scores: (min: 11, avg: 168.58, max: 500)
#
# Run: 525, exploration: 0.02, score: 500
# Scores: (min: 11, avg: 172.19, max: 500)
#
# Run: 526, exploration: 0.02, score: 33
# Scores: (min: 11, avg: 169.45, max: 500)
#
# Run: 527, exploration: 0.02, score: 102
# Scores: (min: 11, avg: 168.37, max: 500)
#
# Run: 528, exploration: 0.02, score: 99
# Scores: (min: 11, avg: 167.99, max: 500)
#
# Run: 529, exploration: 0.02, score: 120
# Scores: (min: 11, avg: 168.38, max: 500)
#
# Run: 530, exploration: 0.02, score: 238
# Scores: (min: 11, avg: 167.07, max: 500)
#
# Run: 531, exploration: 0.02, score: 11
# Scores: (min: 11, avg: 162.18, max: 500)
#
# Run: 532, exploration: 0.02, score: 52
# Scores: (min: 11, avg: 158.7, max: 500)
#
# Run: 533, exploration: 0.02, score: 224
# Scores: (min: 11, avg: 159.25, max: 500)
#
# Run: 534, exploration: 0.02, score: 49
# Scores: (min: 11, avg: 158.24, max: 500)
#
# Run: 535, exploration: 0.02, score: 169
# Scores: (min: 11, avg: 158.31, max: 500)
#
# Run: 536, exploration: 0.02, score: 158
# Scores: (min: 11, avg: 158.58, max: 500)
#
# Run: 537, exploration: 0.02, score: 152
# Scores: (min: 11, avg: 158.34, max: 500)
#
# Run: 538, exploration: 0.02, score: 52
# Scores: (min: 11, avg: 153.86, max: 500)
#
# Run: 539, exploration: 0.02, score: 123
# Scores: (min: 11, avg: 153.18, max: 500)
#
# Run: 540, exploration: 0.02, score: 62
# Scores: (min: 11, avg: 152.43, max: 500)
#
# Run: 541, exploration: 0.02, score: 327
# Scores: (min: 11, avg: 154.48, max: 500)
#
# Run: 542, exploration: 0.02, score: 204
# Scores: (min: 11, avg: 154.53, max: 500)
#
# Run: 543, exploration: 0.02, score: 126
# Scores: (min: 11, avg: 153.22, max: 500)
#
# Run: 544, exploration: 0.02, score: 146
# Scores: (min: 11, avg: 151.4, max: 500)
#
# Run: 545, exploration: 0.02, score: 308
# Scores: (min: 11, avg: 149.48, max: 500)
#
# Run: 546, exploration: 0.02, score: 17
# Scores: (min: 11, avg: 148.01, max: 500)
#
# Run: 547, exploration: 0.02, score: 106
# Scores: (min: 11, avg: 144.07, max: 500)
#
# Run: 548, exploration: 0.02, score: 181
# Scores: (min: 11, avg: 144.14, max: 500)
#
# Run: 549, exploration: 0.02, score: 149
# Scores: (min: 11, avg: 143.42, max: 500)
#
# Run: 550, exploration: 0.02, score: 190
# Scores: (min: 11, avg: 143.85, max: 500)
#
# Run: 551, exploration: 0.02, score: 71
# Scores: (min: 11, avg: 142.99, max: 500)
#
# Run: 552, exploration: 0.02, score: 500
# Scores: (min: 11, avg: 146.58, max: 500)
#
# Run: 553, exploration: 0.02, score: 250
# Scores: (min: 11, avg: 147.03, max: 500)
#
# Run: 554, exploration: 0.02, score: 500
# Scores: (min: 11, avg: 150.53, max: 500)
#
# Run: 555, exploration: 0.02, score: 201
# Scores: (min: 11, avg: 151.83, max: 500)
#
# Run: 556, exploration: 0.02, score: 223
# Scores: (min: 11, avg: 153.72, max: 500)
#
# Run: 557, exploration: 0.02, score: 140
# Scores: (min: 11, avg: 152.71, max: 500)
#
# Run: 558, exploration: 0.02, score: 125
# Scores: (min: 11, avg: 152.35, max: 500)
#
# Run: 559, exploration: 0.02, score: 141
# Scores: (min: 11, avg: 150.99, max: 500)
#
# Run: 560, exploration: 0.02, score: 218
# Scores: (min: 11, avg: 151.81, max: 500)
#
# Run: 561, exploration: 0.02, score: 178
# Scores: (min: 11, avg: 152.02, max: 500)
#
# Run: 562, exploration: 0.02, score: 206
# Scores: (min: 11, avg: 152.74, max: 500)
#
# Run: 563, exploration: 0.02, score: 301
# Scores: (min: 11, avg: 154.6, max: 500)
#
# Run: 564, exploration: 0.02, score: 152
# Scores: (min: 11, avg: 153.5, max: 500)
#
# Run: 565, exploration: 0.02, score: 102
# Scores: (min: 11, avg: 153.24, max: 500)
#
# Run: 566, exploration: 0.02, score: 239
# Scores: (min: 11, avg: 154.03, max: 500)
#
# Run: 567, exploration: 0.02, score: 15
# Scores: (min: 11, avg: 152.53, max: 500)
#
# Run: 568, exploration: 0.02, score: 66
# Scores: (min: 11, avg: 151.52, max: 500)
#
# Run: 569, exploration: 0.02, score: 104
# Scores: (min: 11, avg: 151.71, max: 500)
#
# Run: 570, exploration: 0.02, score: 35
# Scores: (min: 11, avg: 150.34, max: 500)
#
# Run: 571, exploration: 0.02, score: 73
# Scores: (min: 11, avg: 149.6, max: 500)
#
# Run: 572, exploration: 0.02, score: 173
# Scores: (min: 11, avg: 150.29, max: 500)
#
# Run: 573, exploration: 0.02, score: 21
# Scores: (min: 11, avg: 149.51, max: 500)
#
# Run: 574, exploration: 0.02, score: 157
# Scores: (min: 11, avg: 149.86, max: 500)
#
# Run: 575, exploration: 0.02, score: 28
# Scores: (min: 11, avg: 149.79, max: 500)
#
# Run: 576, exploration: 0.02, score: 153
# Scores: (min: 11, avg: 151.02, max: 500)
#
# Run: 577, exploration: 0.02, score: 274
# Scores: (min: 11, avg: 153, max: 500)
#
# Run: 578, exploration: 0.02, score: 172
# Scores: (min: 11, avg: 153.43, max: 500)
#
# Run: 579, exploration: 0.02, score: 18
# Scores: (min: 11, avg: 152.31, max: 500)
#
# Run: 580, exploration: 0.02, score: 185
# Scores: (min: 11, avg: 153.34, max: 500)
#
# Run: 581, exploration: 0.02, score: 183
# Scores: (min: 11, avg: 154.08, max: 500)
#
# Run: 582, exploration: 0.02, score: 119
# Scores: (min: 11, avg: 154.13, max: 500)
#
# Run: 583, exploration: 0.02, score: 169
# Scores: (min: 11, avg: 155.51, max: 500)
#
# Run: 584, exploration: 0.02, score: 138
# Scores: (min: 11, avg: 155.42, max: 500)
#
# Run: 585, exploration: 0.02, score: 180
# Scores: (min: 11, avg: 155.56, max: 500)
#
# Run: 586, exploration: 0.02, score: 115
# Scores: (min: 11, avg: 155.94, max: 500)
#
# Run: 587, exploration: 0.02, score: 328
# Scores: (min: 11, avg: 158.07, max: 500)
#
# Run: 588, exploration: 0.02, score: 276
# Scores: (min: 11, avg: 158.57, max: 500)
#
# Run: 589, exploration: 0.02, score: 500
# ...
# Scores: (min: 8, avg: 39.71, max: 225)
#
# Run: 1079, exploration: 0.02, score: 92
# Scores: (min: 8, avg: 40.53, max: 225)
#
# Run: 1080, exploration: 0.02, score: 101
# Scores: (min: 8, avg: 41.45, max: 225)
#
# Run: 1081, exploration: 0.02, score: 77
# Scores: (min: 8, avg: 42.12, max: 225)
#
# Run: 1082, exploration: 0.02, score: 70
# Scores: (min: 8, avg: 42.72, max: 225)
#
# Run: 1083, exploration: 0.02, score: 102
# Scores: (min: 8, avg: 43.64, max: 225)
#
# Run: 1084, exploration: 0.02, score: 105
# Scores: (min: 8, avg: 44.59, max: 225)
#
# Run: 1085, exploration: 0.02, score: 129
# Scores: (min: 8, avg: 45.78, max: 225)
#
# Run: 1086, exploration: 0.02, score: 269
# Scores: (min: 8, avg: 48.39, max: 269)
#
# Run: 1087, exploration: 0.02, score: 131
# Scores: (min: 8, avg: 49.61, max: 269)
#
# Run: 1088, exploration: 0.02, score: 147
# Scores: (min: 8, avg: 50.97, max: 269)
#
# Run: 1089, exploration: 0.02, score: 119
# Scores: (min: 8, avg: 52.08, max: 269)
#
# Run: 1090, exploration: 0.02, score: 190
# Scores: (min: 8, avg: 53.88, max: 269)
#
# Run: 1091, exploration: 0.02, score: 142
# Scores: (min: 8, avg: 55.21, max: 269)
#
# Run: 1092, exploration: 0.02, score: 68
# Scores: (min: 8, avg: 55.79, max: 269)
#
# Run: 1093, exploration: 0.02, score: 117
# Scores: (min: 8, avg: 56.85, max: 269)
#
# Run: 1094, exploration: 0.02, score: 206
# Scores: (min: 8, avg: 58.82, max: 269)
#
# Run: 1095, exploration: 0.02, score: 218
# Scores: (min: 8, avg: 60.91, max: 269)
#
# Run: 1096, exploration: 0.02, score: 150
# Scores: (min: 8, avg: 62.33, max: 269)
#
# Run: 1097, exploration: 0.02, score: 171
# Scores: (min: 8, avg: 63.93, max: 269)
#
# Run: 1098, exploration: 0.02, score: 241
# Scores: (min: 8, avg: 66.24, max: 269)
#
# Run: 1099, exploration: 0.02, score: 153
# Scores: (min: 8, avg: 67.67, max: 269)
#
# Run: 1100, exploration: 0.02, score: 261
# Scores: (min: 8, avg: 70.19, max: 269)
#
# Run: 1101, exploration: 0.02, score: 158
# Scores: (min: 8, avg: 71.68, max: 269)
#
# Run: 1102, exploration: 0.02, score: 158
# Scores: (min: 8, avg: 73.16, max: 269)
#
# Run: 1103, exploration: 0.02, score: 162
# Scores: (min: 8, avg: 74.69, max: 269)
#
# Run: 1104, exploration: 0.02, score: 181
# Scores: (min: 8, avg: 76.4, max: 269)
#
# Run: 1105, exploration: 0.02, score: 162
# Scores: (min: 8, avg: 77.94, max: 269)
#
# Run: 1106, exploration: 0.02, score: 196
# Scores: (min: 8, avg: 79.79, max: 269)
#
# Run: 1107, exploration: 0.02, score: 147
# Scores: (min: 8, avg: 81.16, max: 269)
#
# Run: 1108, exploration: 0.02, score: 105
# Scores: (min: 8, avg: 82.11, max: 269)
#
# Run: 1109, exploration: 0.02, score: 233
# Scores: (min: 8, avg: 84.34, max: 269)
#
# Run: 1110, exploration: 0.02, score: 233
# Scores: (min: 8, avg: 86.57, max: 269)
#
# Run: 1111, exploration: 0.02, score: 211
# Scores: (min: 8, avg: 88.57, max: 269)
#
# Run: 1112, exploration: 0.02, score: 109
# Scores: (min: 8, avg: 89.13, max: 269)
#
# Run: 1113, exploration: 0.02, score: 191
# Scores: (min: 8, avg: 90.46, max: 269)
#
# Run: 1114, exploration: 0.02, score: 404
# Scores: (min: 8, avg: 94.39, max: 404)
#
# Run: 1115, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 94.41, max: 404)
#
# Run: 1116, exploration: 0.02, score: 223
# Scores: (min: 8, avg: 96.27, max: 404)
#
# Run: 1117, exploration: 0.02, score: 211
# Scores: (min: 8, avg: 97.98, max: 404)
#
# Run: 1118, exploration: 0.02, score: 297
# Scores: (min: 8, avg: 100.84, max: 404)
#
# Run: 1119, exploration: 0.02, score: 115
# Scores: (min: 8, avg: 101.84, max: 404)
#
# Run: 1120, exploration: 0.02, score: 64
# Scores: (min: 8, avg: 102.29, max: 404)
#
# Run: 1121, exploration: 0.02, score: 13
# Scores: (min: 8, avg: 102.33, max: 404)
#
# Run: 1122, exploration: 0.02, score: 28
# Scores: (min: 8, avg: 102.52, max: 404)
#
# Run: 1123, exploration: 0.02, score: 54
# Scores: (min: 8, avg: 102.8, max: 404)
#
# Run: 1124, exploration: 0.02, score: 20
# Scores: (min: 8, avg: 102.89, max: 404)
# Run: 1125, exploration: 0.02, score: 115
# Scores: (min: 8, avg: 103.94, max: 404)
#
# Run: 1126, exploration: 0.02, score: 244
# Scores: (min: 8, avg: 105.71, max: 404)
#
# Run: 1127, exploration: 0.02, score: 86
# Scores: (min: 8, avg: 106.46, max: 404)
#
# Run: 1128, exploration: 0.02, score: 141
# Scores: (min: 8, avg: 107.77, max: 404)
#
# Run: 1129, exploration: 0.02, score: 268
# Scores: (min: 8, avg: 110.29, max: 404)
#
# Run: 1130, exploration: 0.02, score: 238
# Scores: (min: 8, avg: 112.54, max: 404)
#
# Run: 1131, exploration: 0.02, score: 230
# Scores: (min: 8, avg: 114.73, max: 404)
#
# Run: 1132, exploration: 0.02, score: 464
# Scores: (min: 8, avg: 119.16, max: 464)
#
# Run: 1133, exploration: 0.02, score: 116
# Scores: (min: 8, avg: 120.22, max: 464)
#
# Run: 1134, exploration: 0.02, score: 34
# Scores: (min: 8, avg: 120.32, max: 464)
#
# Run: 1135, exploration: 0.02, score: 149
# Scores: (min: 8, avg: 121.64, max: 464)
#
# Run: 1136, exploration: 0.02, score: 500
# Scores: (min: 8, avg: 126.54, max: 500)
#
# Run: 1137, exploration: 0.02, score: 144
# Scores: (min: 8, avg: 127.88, max: 500)
#
# Run: 1138, exploration: 0.02, score: 329
# Scores: (min: 8, avg: 131.06, max: 500)
#
# Run: 1139, exploration: 0.02, score: 169
# Scores: (min: 8, avg: 132.62, max: 500)
#
# Run: 1140, exploration: 0.02, score: 162
# Scores: (min: 8, avg: 134.01, max: 500)
#
# Run: 1141, exploration: 0.02, score: 51
# Scores: (min: 8, avg: 134.22, max: 500)
#
# Run: 1142, exploration: 0.02, score: 145
# Scores: (min: 8, avg: 135.49, max: 500)
#
# Run: 1143, exploration: 0.02, score: 294
# Scores: (min: 8, avg: 138.25, max: 500)
#
# Run: 1144, exploration: 0.02, score: 138
# Scores: (min: 8, avg: 139.45, max: 500)
#
# Run: 1145, exploration: 0.02, score: 135
# Scores: (min: 8, avg: 140.71, max: 500)
#
# Run: 1146, exploration: 0.02, score: 158
# Scores: (min: 8, avg: 142.03, max: 500)
#
# Run: 1147, exploration: 0.02, score: 173
# Scores: (min: 8, avg: 143.48, max: 500)
#
# Run: 1148, exploration: 0.02, score: 219
# Scores: (min: 8, avg: 145.55, max: 500)
#
# Run: 1149, exploration: 0.02, score: 200
# Scores: (min: 8, avg: 147.04, max: 500)
#
# Run: 1150, exploration: 0.02, score: 250
# Scores: (min: 8, avg: 149.14, max: 500)
#
# Run: 1151, exploration: 0.02, score: 156
# Scores: (min: 8, avg: 150.43, max: 500)
#
# Run: 1152, exploration: 0.02, score: 97
# Scores: (min: 8, avg: 150.27, max: 500)
#
# Run: 1153, exploration: 0.02, score: 161
# Scores: (min: 8, avg: 150.63, max: 500)
#
# Run: 1154, exploration: 0.02, score: 115
# Scores: (min: 8, avg: 151.52, max: 500)
#
# Run: 1155, exploration: 0.02, score: 41
# Scores: (min: 11, avg: 151.85, max: 500)
#
# Run: 1156, exploration: 0.02, score: 38
# Scores: (min: 11, avg: 151.94, max: 500)
#
# Run: 1157, exploration: 0.02, score: 22
# Scores: (min: 11, avg: 149.91, max: 500)
#
# Run: 1158, exploration: 0.02, score: 173
# Scores: (min: 11, avg: 150.58, max: 500)
#
# Run: 1159, exploration: 0.02, score: 108
# Scores: (min: 11, avg: 150.56, max: 500)
#
# Run: 1160, exploration: 0.02, score: 114
# Scores: (min: 11, avg: 150.63, max: 500)
#
# Run: 1161, exploration: 0.02, score: 17
# Scores: (min: 11, avg: 149.59, max: 500)
#
# Run: 1162, exploration: 0.02, score: 10
# Scores: (min: 10, avg: 148.2, max: 500)
#
# Run: 1163, exploration: 0.02, score: 155
# Scores: (min: 10, avg: 148.49, max: 500)
#
# Run: 1164, exploration: 0.02, score: 37
# Scores: (min: 10, avg: 147.27, max: 500)
#
# Run: 1165, exploration: 0.02, score: 158
# Scores: (min: 10, avg: 147.31, max: 500)
#
# Run: 1166, exploration: 0.02, score: 158
# Scores: (min: 10, avg: 147.82, max: 500)
#
# Run: 1167, exploration: 0.02, score: 212
# Scores: (min: 10, avg: 149.01, max: 500)
#
# Run: 1168, exploration: 0.02, score: 192
# Scores: (min: 10, avg: 149.78, max: 500)
#
# Run: 1169, exploration: 0.02, score: 289
# Scores: (min: 10, avg: 152.56, max: 500)
#
# Run: 1170, exploration: 0.02, score: 144
# Scores: (min: 10, avg: 153.82, max: 500)
#
# Run: 1171, exploration: 0.02, score: 29
# Scores: (min: 10, avg: 153.16, max: 500)
#
# Run: 1172, exploration: 0.02, score: 113
# Scores: (min: 10, avg: 153.28, max: 500)
#
# Run: 1173, exploration: 0.02, score: 171
# Scores: (min: 10, avg: 153.83, max: 500)
#
# Run: 1174, exploration: 0.02, score: 302
# Scores: (min: 10, avg: 155.7, max: 500)
#
# Run: 1175, exploration: 0.02, score: 217
# Scores: (min: 10, avg: 156.6, max: 500)
#
# Run: 1176, exploration: 0.02, score: 250
# Scores: (min: 10, avg: 158.05, max: 500)
#
# Run: 1177, exploration: 0.02, score: 272
# Scores: (min: 10, avg: 159.63, max: 500)
#
# Run: 1178, exploration: 0.02, score: 307
# Scores: (min: 10, avg: 161.57, max: 500)
#
# Run: 1179, exploration: 0.02, score: 170
# Scores: (min: 10, avg: 162.35, max: 500)
#
# Run: 1180, exploration: 0.02, score: 118
# Scores: (min: 10, avg: 162.52, max: 500)
#
# Run: 1181, exploration: 0.02, score: 178
# Scores: (min: 10, avg: 163.53, max: 500)
#
# Run: 1182, exploration: 0.02, score: 232
# Scores: (min: 10, avg: 165.15, max: 500)
#
# Run: 1183, exploration: 0.02, score: 179
# Scores: (min: 10, avg: 165.92, max: 500)
#
# Run: 1184, exploration: 0.02, score: 168
# Scores: (min: 10, avg: 166.55, max: 500)
#
# Run: 1185, exploration: 0.02, score: 246
# Scores: (min: 10, avg: 167.72, max: 500)
#
# Run: 1186, exploration: 0.02, score: 259
# Scores: (min: 10, avg: 167.62, max: 500)
#
# Run: 1187, exploration: 0.02, score: 72
# Scores: (min: 10, avg: 167.03, max: 500)
#
# Run: 1188, exploration: 0.02, score: 21
# Scores: (min: 10, avg: 165.77, max: 500)
#
# Run: 1189, exploration: 0.02, score: 92
# Scores: (min: 10, avg: 165.5, max: 500)
#
# Run: 1190, exploration: 0.02, score: 158
# Scores: (min: 10, avg: 165.18, max: 500)
#
# Run: 1191, exploration: 0.02, score: 139
# Scores: (min: 10, avg: 165.15, max: 500)
#
# Run: 1192, exploration: 0.02, score: 313
# Scores: (min: 10, avg: 167.6, max: 500)
#
# Run: 1193, exploration: 0.02, score: 134
# Scores: (min: 10, avg: 167.77, max: 500)
#
# Run: 1194, exploration: 0.02, score: 236
# Scores: (min: 10, avg: 168.07, max: 500)
#
# Run: 1195, exploration: 0.02, score: 121
# Scores: (min: 10, avg: 167.1, max: 500)
#
# Run: 1196, exploration: 0.02, score: 182
# Scores: (min: 10, avg: 167.42, max: 500)
#
# Run: 1197, exploration: 0.02, score: 367
# Scores: (min: 10, avg: 169.38, max: 500)
#
# Run: 1198, exploration: 0.02, score: 195
# Scores: (min: 10, avg: 168.92, max: 500)
#
# Run: 1199, exploration: 0.02, score: 114
# Scores: (min: 10, avg: 168.53, max: 500)
#
# Run: 1200, exploration: 0.02, score: 184
# Scores: (min: 10, avg: 167.76, max: 500)
#
# Run: 1201, exploration: 0.02, score: 139
# Scores: (min: 10, avg: 167.57, max: 500)
#
# Run: 1202, exploration: 0.02, score: 129
# Scores: (min: 10, avg: 167.28, max: 500)
#
# Run: 1203, exploration: 0.02, score: 111
# Scores: (min: 10, avg: 166.77, max: 500)
#
# Run: 1204, exploration: 0.02, score: 121
# Scores: (min: 10, avg: 166.17, max: 500)
#
# Run: 1205, exploration: 0.02, score: 396
# Scores: (min: 10, avg: 168.51, max: 500)
#
# Run: 1206, exploration: 0.02, score: 235
# Scores: (min: 10, avg: 168.9, max: 500)
#
# Run: 1207, exploration: 0.02, score: 149
# Scores: (min: 10, avg: 168.92, max: 500)
#
# Run: 1208, exploration: 0.02, score: 103
# Scores: (min: 10, avg: 168.9, max: 500)
#
# Run: 1209, exploration: 0.02, score: 151
# Scores: (min: 10, avg: 168.08, max: 500)
#
# Run: 1210, exploration: 0.02, score: 35
# Scores: (min: 10, avg: 166.1, max: 500)
#
# Run: 1211, exploration: 0.02, score: 42
# Scores: (min: 10, avg: 164.41, max: 500)
#
# Run: 1212, exploration: 0.02, score: 149
# Scores: (min: 10, avg: 164.81, max: 500)
#
# Run: 1213, exploration: 0.02, score: 43
# Scores: (min: 10, avg: 163.33, max: 500)
#
# Run: 1214, exploration: 0.02, score: 15
# Scores: (min: 10, avg: 159.44, max: 500)
#
# Run: 1215, exploration: 0.02, score: 134
# Scores: (min: 10, avg: 160.65, max: 500)
#
# Run: 1216, exploration: 0.02, score: 165
# Scores: (min: 10, avg: 160.07, max: 500)
#
# Run: 1217, exploration: 0.02, score: 226
# Scores: (min: 10, avg: 160.22, max: 500)
#
# Run: 1218, exploration: 0.02, score: 189
# Scores: (min: 10, avg: 159.14, max: 500)
#
# Run: 1219, exploration: 0.02, score: 170
# Scores: (min: 10, avg: 159.69, max: 500)
#
# Run: 1220, exploration: 0.02, score: 298
# Scores: (min: 10, avg: 162.03, max: 500)
#
# Run: 1221, exploration: 0.02, score: 88
# Scores: (min: 10, avg: 162.78, max: 500)
#
# Run: 1222, exploration: 0.02, score: 16
# Scores: (min: 10, avg: 162.66, max: 500)
#
# Run: 1223, exploration: 0.02, score: 99
# Scores: (min: 10, avg: 163.11, max: 500)
#
# Run: 1224, exploration: 0.02, score: 171
# Scores: (min: 10, avg: 164.62, max: 500)
# Run: 1225, exploration: 0.02, score: 118
# Scores: (min: 10, avg: 164.65, max: 500)
#
# Run: 1226, exploration: 0.02, score: 67
# Scores: (min: 10, avg: 162.88, max: 500)
#
# Run: 1227, exploration: 0.02, score: 299
# Scores: (min: 10, avg: 165.01, max: 500)
#
# Run: 1228, exploration: 0.02, score: 172
# Scores: (min: 10, avg: 165.32, max: 500)
#
# Run: 1229, exploration: 0.02, score: 220
# Scores: (min: 10, avg: 164.84, max: 500)
#
# Run: 1230, exploration: 0.02, score: 57
# Scores: (min: 10, avg: 163.03, max: 500)
#
# Run: 1231, exploration: 0.02, score: 13
# Scores: (min: 10, avg: 160.86, max: 500)
#
# Run: 1232, exploration: 0.02, score: 102
# Scores: (min: 10, avg: 157.24, max: 500)
#
# Run: 1233, exploration: 0.02, score: 104
# Scores: (min: 10, avg: 157.12, max: 500)
#
# Run: 1234, exploration: 0.02, score: 283
# Scores: (min: 10, avg: 159.61, max: 500)
#
# Run: 1235, exploration: 0.02, score: 408
# Scores: (min: 10, avg: 162.2, max: 500)
#
# Run: 1236, exploration: 0.02, score: 259
# Scores: (min: 10, avg: 159.79, max: 408)
#
# Run: 1237, exploration: 0.02, score: 186
# Scores: (min: 10, avg: 160.21, max: 408)
#
# Run: 1238, exploration: 0.02, score: 161
# Scores: (min: 10, avg: 158.53, max: 408)
#
# Run: 1239, exploration: 0.02, score: 95
# Scores: (min: 10, avg: 157.79, max: 408)
#
# Run: 1240, exploration: 0.02, score: 358
# Scores: (min: 10, avg: 159.75, max: 408)
#
# Run: 1241, exploration: 0.02, score: 165
# Scores: (min: 10, avg: 160.89, max: 408)
#
# Run: 1242, exploration: 0.02, score: 168
# Scores: (min: 10, avg: 161.12, max: 408)
#
# Run: 1243, exploration: 0.02, score: 16
# Scores: (min: 10, avg: 158.34, max: 408)
#
# Run: 1244, exploration: 0.02, score: 127
# Scores: (min: 10, avg: 158.23, max: 408)
#
# Run: 1245, exploration: 0.02, score: 56
# Scores: (min: 10, avg: 157.44, max: 408)
#
# Run: 1246, exploration: 0.02, score: 129
# Scores: (min: 10, avg: 157.15, max: 408)
#
# Run: 1247, exploration: 0.02, score: 165
# Scores: (min: 10, avg: 157.07, max: 408)
#
# Run: 1248, exploration: 0.02, score: 339
# Scores: (min: 10, avg: 158.27, max: 408)
#
# Run: 1249, exploration: 0.02, score: 333
# Scores: (min: 10, avg: 159.6, max: 408)
#
# Run: 1250, exploration: 0.02, score: 288
# Scores: (min: 10, avg: 159.98, max: 408)
#
# Run: 1251, exploration: 0.02, score: 151
# Scores: (min: 10, avg: 159.93, max: 408)
#
# Run: 1252, exploration: 0.02, score: 350
# Scores: (min: 10, avg: 162.46, max: 408)
#
# Run: 1253, exploration: 0.02, score: 14
# Scores: (min: 10, avg: 160.99, max: 408)
#
# Run: 1254, exploration: 0.02, score: 105
# Scores: (min: 10, avg: 160.89, max: 408)
#
# Run: 1255, exploration: 0.02, score: 125
# Scores: (min: 10, avg: 161.73, max: 408)
#
# Run: 1256, exploration: 0.02, score: 99
# Scores: (min: 10, avg: 162.34, max: 408)
#
# Run: 1257, exploration: 0.02, score: 108
# Scores: (min: 10, avg: 163.2, max: 408)
#
# Run: 1258, exploration: 0.02, score: 131
# Scores: (min: 10, avg: 162.78, max: 408)
#
# Run: 1259, exploration: 0.02, score: 45
# Scores: (min: 10, avg: 162.15, max: 408)
#
# Run: 1260, exploration: 0.02, score: 194
# Scores: (min: 10, avg: 162.95, max: 408)
#
# Run: 1261, exploration: 0.02, score: 245
# Scores: (min: 10, avg: 165.23, max: 408)
#
# Run: 1262, exploration: 0.02, score: 42
# Scores: (min: 13, avg: 165.55, max: 408)
#
# Run: 1263, exploration: 0.02, score: 34
# Scores: (min: 13, avg: 164.34, max: 408)
#
# Run: 1264, exploration: 0.02, score: 18
# Scores: (min: 13, avg: 164.15, max: 408)
#
# Run: 1265, exploration: 0.02, score: 28
# Scores: (min: 13, avg: 162.85, max: 408)
#
# Run: 1266, exploration: 0.02, score: 126
# Scores: (min: 13, avg: 162.53, max: 408)
#
# Run: 1267, exploration: 0.02, score: 110
# Scores: (min: 13, avg: 161.51, max: 408)
#
# Run: 1268, exploration: 0.02, score: 175
# Scores: (min: 13, avg: 161.34, max: 408)
#
# Run: 1269, exploration: 0.02, score: 182
# Scores: (min: 13, avg: 160.27, max: 408)
#
# Run: 1270, exploration: 0.02, score: 117
# Scores: (min: 13, avg: 160, max: 408)
#
# Run: 1271, exploration: 0.02, score: 131
# Scores: (min: 13, avg: 161.02, max: 408)
#
# Run: 1272, exploration: 0.02, score: 237
# Scores: (min: 13, avg: 162.26, max: 408)

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# ## Analysis:
#
#    #### Explain how reinforcement learning concepts apply to the cartpole problem.
#
#    * ###### What is the goal of the agent in this case?
#
#    The goal of the agent in this case is to balance the pole for as long as possible, by moving
# the cart left or right (Surma 2019). The agent receives a reward for each time-step that the pole
# remains balanced.
#
#
#    * ###### What are the various state values?
#
#    The state values here are the positions and velocities of the cart and the pole. These values
# are used to represent the current state of the system, which the agent must use to make
# decisions.
#
#
#    * ###### What are the possible actions that can be performed?
#
#    The possible actions that can be performed by the agent are moving the cart left or right.
# These actions influence the state of the system, and the agent must choose the action that
# maximizes the reward over time.
#
#
#    * ###### What reinforcement algorithm is used for this problem?
#
#    The reinforcement algorithm used for this problem is the deep Q-Learning algorithm or
# DQN (Surma 2019), which is a model-free reinforcement learning algorithm. The DQN updates
# its estimates of the expected reward for each state-action pair over time, based on the
# observed rewards and the expected rewards for the next state. The agent chooses the action
# that maximizes the expected reward for each state, until it reaches a solution.
#
# #### Analyze how experience replay is applied to the cartpole problem.
#
#
#    * ###### How does experience replay work in this algorithm?
#
#    Experience replay is a key component in the DQN, including those applied to the Cartpole
# problem. In the Cartpole problem, the experience replay works by storing the agent's
# experiences, which consist of the state, action, reward, and next state, in small batches to avoid
# data skew (Wang 2021).
#
#
#    * ###### What is the effect of introducing a discount factor for calculating the future rewards?
#
#    The effect of introducing a discount factor is that it determines the relative importance of
# future rewards compared to immediate rewards (SALLOUM 2021). A discount factor of 1 means
# that future rewards are equally important as immediate rewards, while a discount factor less
# than 1 means that future rewards are worth less than immediate rewards. This allows the agent
# to trade off short-term rewards for long-term rewards and helps it to make more informed
# decisions.
#
# #### Analyze how neural networks are used in deep Q-learning.
#
#
#    * ###### Explain the neural network architecture that is used in the cartpole problem.
#
#    Neural networks are often used in DQN to approximate the Q-function, which represents
# the expected reward for taking a particular action in a particular state. In this example, a simple
# feedforward neural network is used as the function approximator. The input layer consists of
# the state values (e.g., the positions and velocities of the cart and pole), and the output layer
# consists of the estimated expected reward for each action. There may be several hidden layers
# with non-linear activation functions, such as rectified linear units (ReLU), to help the network
# capture complex relationships between the inputs and outputs.
#
#
#    * ###### How does the neural network make the Q-learning algorithm more efficient?
#
#    The neural network makes the Q-learning algorithm more efficient by allowing it to
# generalize from its experiences, rather than memorizing them. By updating its parameters
# based on the observed rewards and the expected rewards, the network can learn to produce
# accurate estimates of the expected reward for each state-action pair, even in states that it has
# never seen before.
#
#
#    * ###### What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#
#
#    The learning rate determines the speed at which the network updates its parameters based
# on the observed rewards and the expected rewards. A higher learning rate means that the
# network updates its parameters more quickly, while a lower learning rate means that the
# network updates its parameters slowly requiring more epochs (Brownlee 2019)
#
#    Increasing the learning rate can cause the network to converge to a solution more quickly,
# but it may also lead to instability or oscillations in the estimated Q-values. Decreasing the
# learning rate can make the network converge more slowly, but it can also lead to a more stable
# and accurate solution.
#
#
# #### References:
#
#    Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN -
# deep Q-learning). Medium. Retrieved February 4, 2023, from
# https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
#
#    Wang, M. (2021, October 3). Deep Q-learning tutorial: Mindqn. Medium. Retrieved
# February 4, 2023, from https://towardsdatascience.com/deep-q-learning-tutorial-mindqn-2a4c855abffc
#
#    SALLOUM, Z. (2021, December 12). Basics of reinforcement learning, the easy way.
# Medium. Retrieved February 4, 2023, from https://zsalloum.medium.com/basics-of-reinforcement-learning-the-easy-way-fb3a0a44f30e
#
#    Brownlee, J. (2020, September 11). Understand the impact of learning rate on neural
# network performance. MachineLearningMastery.com. Retrieved February 4, 2023, from
# https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/
